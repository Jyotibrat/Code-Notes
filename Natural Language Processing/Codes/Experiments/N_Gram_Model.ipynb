# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Install nltk (only needed first time in Colab)
# !pip install nltk

# Import necessary libraries
import nltk
import re
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

# Download tokenizer data
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Define the three corpora
corpus1 = "Write a python program to find all unigrams, bigrams and trigrams present in the given corpus."
corpus2 = "The students were studying happiness and replaying recorded lectures."
corpus3 = "NLP is amazing!!! यह बहुत अच्छा है 2025 @AI"

# Combine all corpora into one single corpus
combined_corpus = corpus1 + " " + corpus2 + " " + corpus3

print("Combined Corpus:\n")
print(combined_corpus)
# Out:
# Combined Corpus:
#
# Write a python program to find all unigrams, bigrams and trigrams present in the given corpus. The students were studying happiness and replaying recorded lectures. NLP is amazing!!! यह बहुत अच्छा है 2025 @AI

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Convert text to lowercase
combined_corpus = combined_corpus.lower()

# Remove special characters except Hindi characters and numbers
cleaned_text = re.sub(r"[^\w\s\u0900-\u097F]", "", combined_corpus)

print("Cleaned Text:\n")
print(cleaned_text)
# Out:
# Cleaned Text:
#
# write a python program to find all unigrams bigrams and trigrams present in the given corpus the students were studying happiness and replaying recorded lectures nlp is amazing यह बहुत अच्छा है 2025 ai

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Tokenize the cleaned text into words
tokens = word_tokenize(cleaned_text)

print("Tokens:\n")
print(tokens)
# Out:
# Tokens:
#
# ['write', 'a', 'python', 'program', 'to', 'find', 'all', 'unigrams', 'bigrams', 'and', 'trigrams', 'present', 'in', 'the', 'given', 'corpus', 'the', 'students', 'were', 'studying', 'happiness', 'and', 'replaying', 'recorded', 'lectures', 'nlp', 'is', 'amazing', 'यह', 'बहुत', 'अच्छा', 'है', '2025', 'ai']

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Generate Unigrams (single words)
unigrams = list(ngrams(tokens, 1))

print("Unigrams:\n")
print(unigrams)
# Out:
# Unigrams:
#
# [('write',), ('a',), ('python',), ('program',), ('to',), ('find',), ('all',), ('unigrams',), ('bigrams',), ('and',), ('trigrams',), ('present',), ('in',), ('the',), ('given',), ('corpus',), ('the',), ('students',), ('were',), ('studying',), ('happiness',), ('and',), ('replaying',), ('recorded',), ('lectures',), ('nlp',), ('is',), ('amazing',), ('यह',), ('बहुत',), ('अच्छा',), ('है',), ('2025',), ('ai',)]

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Generate Bigrams (pairs of consecutive words)
bigrams = list(ngrams(tokens, 2))

print("Bigrams:\n")
print(bigrams)
# Out:
# Bigrams:
#
# [('write', 'a'), ('a', 'python'), ('python', 'program'), ('program', 'to'), ('to', 'find'), ('find', 'all'), ('all', 'unigrams'), ('unigrams', 'bigrams'), ('bigrams', 'and'), ('and', 'trigrams'), ('trigrams', 'present'), ('present', 'in'), ('in', 'the'), ('the', 'given'), ('given', 'corpus'), ('corpus', 'the'), ('the', 'students'), ('students', 'were'), ('were', 'studying'), ('studying', 'happiness'), ('happiness', 'and'), ('and', 'replaying'), ('replaying', 'recorded'), ('recorded', 'lectures'), ('lectures', 'nlp'), ('nlp', 'is'), ('is', 'amazing'), ('amazing', 'यह'), ('यह', 'बहुत'), ('बहुत', 'अच्छा'), ('अच्छा', 'है'), ('है', '2025'), ('2025', 'ai')]

# %%
# Name: Bindupautra Jyotibrat
# Registration No.: 23BAI10963

# Generate Trigrams (three consecutive words)
trigrams = list(ngrams(tokens, 3))

print("Trigrams:\n")
print(trigrams)
# Out:
# Trigrams:
#
# [('write', 'a', 'python'), ('a', 'python', 'program'), ('python', 'program', 'to'), ('program', 'to', 'find'), ('to', 'find', 'all'), ('find', 'all', 'unigrams'), ('all', 'unigrams', 'bigrams'), ('unigrams', 'bigrams', 'and'), ('bigrams', 'and', 'trigrams'), ('and', 'trigrams', 'present'), ('trigrams', 'present', 'in'), ('present', 'in', 'the'), ('in', 'the', 'given'), ('the', 'given', 'corpus'), ('given', 'corpus', 'the'), ('corpus', 'the', 'students'), ('the', 'students', 'were'), ('students', 'were', 'studying'), ('were', 'studying', 'happiness'), ('studying', 'happiness', 'and'), ('happiness', 'and', 'replaying'), ('and', 'replaying', 'recorded'), ('replaying', 'recorded', 'lectures'), ('recorded', 'lectures', 'nlp'), ('lectures', 'nlp', 'is'), ('nlp', 'is', 'amazing'), ('is', 'amazing', 'यह'), ('amazing', 'यह', 'बहुत'), ('यह', 'बहुत', 'अच्छा'), ('बहुत', 'अच्छा', 'है'), ('अच्छा', 'है', '2025'), ('है', '2025', 'ai')]
